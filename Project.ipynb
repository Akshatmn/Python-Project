# %%
import random
while True:
    choice = input("Roll the dice (y/n)").lower()
    if choice == 'y':
        die1 = random.randint(1, 6)
        die2 = random.randint(1, 6)
        print(f"({die1},{die2})")
    elif choice == "n":
        print("Thanks for playing")
        break
    else:
        print("Invalid choice")
# Out:
# Roll the dice (y/n) n
# Thanks for playing

# %%
import random
computer_choice = random.randint(1,100)
while True:
    try:
        user_response = int(input("Guess the number between 1 and 100"))
        if user_response>computer_choice:
            print("Too High")
        elif user_response == computer_choice:
            print("Great you got it")
            break
        elif user_response<computer_choice:
            print("Too Low")
    except ValueError:
        print("Please Enter integer value")
